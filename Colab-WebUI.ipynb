# %% [markdown]
# <a href="https://colab.research.google.com/github/oliverzhangzheng-hue/-/blob/main/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:54
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5816, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 5816 (delta 14), reused 5 (delta 5), pack-reused 5788 (from 3)
# Receiving objects: 100% (5816/5816), 14.07 MiB | 18.61 MiB/s, done.
# Resolving deltas: 100% (3334/3334), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.12.2  |       h06a4308_0         125 KB
# ...

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://8e71d602cc7b9f77ae.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s tools/uvr5/webui.py "cuda:0" True 9873 True
# Running on local URL:  http://0.0.0.0:9873
# Running on public URL: https://9bcf9c8a0022cd3be3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)

# %% [markdown]
# # Task
# In order to confirm the current language of the WebUI and then set it to Chinese, the first step is to check the GPT-SoVITS project directory for any language configuration files or settings. This will help identify how to change the language.
#
# List the files in the `/content/GPT-SoVITS` directory.

# %% [markdown]
# ## 检查GPT-SoVITS目录
#
# ### Subtask:
# 检查GPT-SoVITS项目目录下的文件，寻找可能的语言配置文件或相关设置。

# %% [markdown]
# **Reasoning**:
# The subtask is to inspect the GPT-SoVITS project directory for language configuration files or relevant settings. Listing the files and directories is the first step to achieve this.

# %%
# !ls -F /content/GPT-SoVITS
